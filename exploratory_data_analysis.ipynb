# %% [markdown]
# ### Imports

# %%
# Data Handling and Analysis
import pandas as pd 

# Data Visualization 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Datasets

# %%
df_aapl_balance_sheet = pd.read_csv(r'Apple-Stock-Datasets\aapl_balance_sheet.csv')
df_appl_cash_flow = pd.read_csv(r'Apple-Stock-Datasets\aapl_cash_flow.csv')
df_appl_dividends = pd.read_csv(r'Apple-Stock-Datasets\aapl_dividends.csv')
df_appl_historical_data = pd.read_csv(r'Apple-Stock-Datasets\aapl_historical_data.csv')
df_income_statement = pd.read_csv(r'Apple-Stock-Datasets\aapl_income_statement.csv')
df_appl_instituational_ownership = pd.read_csv(r'Apple-Stock-Datasets\aapl_institutional_ownership.csv')
df_appl_master_data = pd.read_csv(r'Apple-Stock-Datasets\aapl_master_dataset.csv')
df_appl_quarterly_earnings = pd.read_csv(r'Apple-Stock-Datasets\aapl_quarterly_financials.csv')
df_appl_splits = pd.read_csv(r'Apple-Stock-Datasets\aapl_splits.csv')
df_appl_stock_price = pd.read_csv(r'Apple-Stock-Datasets\aapl_stock_prices.csv')
df_appl_summary = pd.read_csv(r'Apple-Stock-Datasets\aapl_summary.csv')
df_appl_technical_indicators = pd.read_csv(r'Apple-Stock-Datasets\aapl_technical_indicators.csv')
